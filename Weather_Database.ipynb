# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Get the nearest city.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]). city_name
# If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
print(city)
# Out:
# xining

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6ae8986afd4f8569fe338149f5de8372

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | elizabeth city
# Processing Record 2 of Set 1 | novo oriente
# Processing Record 3 of Set 1 | timmins
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | lavrentiya
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | menongue
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | ginir
# Processing Record 12 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 1 | siparia
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | khowst
# Processing Record 18 of Set 1 | molina
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | aswan
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | clyde river
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | antalaha
# Processing Record 30 of Set 1 | praia
# Processing Record 31 of Set 1 | oksfjord
# Processing Record 32 of Set 1 | burica
# City not found. Skipping...
# Processing Record 33 of Set 1 | atasu
# Processing Record 34 of Set 1 | whyalla
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | taltal
# Processing Record 37 of Set 1 | minab
# Processing Record 38 of Set 1 | san blas
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | bambous virieux
# Processing Record 41 of Set 1 | tual
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | bokspits
# City not found. Skipping...
# Processing Record 47 of Set 1 | filadelfia
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | channel-port aux basques
# Processing Record 50 of Set 1 | taoudenni
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | kavieng
# Processing Record 3 of Set 2 | cherskiy
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | hilo
# Processing Record 9 of Set 2 | am timan
# Processing Record 10 of Set 2 | luderitz
# Processing Record 11 of Set 2 | olinda
# Processing Record 12 of Set 2 | nishihara
# Processing Record 13 of Set 2 | mogzon
# Processing Record 14 of Set 2 | isangel
# Processing Record 15 of Set 2 | talnakh
# Processing Record 16 of Set 2 | jamestown
# Processing Record 17 of Set 2 | daru
# Processing Record 18 of Set 2 | standish
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | riyadh
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | khani
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | floriano
# Processing Record 26 of Set 2 | zlitan
# Processing Record 27 of Set 2 | ilulissat
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | kaitangata
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | bedford
# Processing Record 34 of Set 2 | kodiak
# Processing Record 35 of Set 2 | wattegama
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 2 | coffs harbour
# Processing Record 43 of Set 2 | trelew
# Processing Record 44 of Set 2 | soller
# Processing Record 45 of Set 2 | malakal
# Processing Record 46 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 2 | te anau
# Processing Record 48 of Set 2 | leningradskiy
# Processing Record 49 of Set 2 | busselton
# Processing Record 50 of Set 2 | bluff
# Processing Record 1 of Set 3 | jacqueville
# Processing Record 2 of Set 3 | jalu
# Processing Record 3 of Set 3 | mangrol
# Processing Record 4 of Set 3 | waw
# Processing Record 5 of Set 3 | port augusta
# Processing Record 6 of Set 3 | yar-sale
# Processing Record 7 of Set 3 | santa rosa
# Processing Record 8 of Set 3 | port hardy
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | adelaide
# Processing Record 11 of Set 3 | pogar
# Processing Record 12 of Set 3 | gizo
# Processing Record 13 of Set 3 | grand gaube
# Processing Record 14 of Set 3 | ust-nera
# Processing Record 15 of Set 3 | opuwo
# Processing Record 16 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 17 of Set 3 | aksarka
# Processing Record 18 of Set 3 | paracuru
# Processing Record 19 of Set 3 | vaini
# Processing Record 20 of Set 3 | altamira
# Processing Record 21 of Set 3 | urusha
# Processing Record 22 of Set 3 | ahipara
# Processing Record 23 of Set 3 | vitim
# Processing Record 24 of Set 3 | guerrero negro
# Processing Record 25 of Set 3 | fortuna
# Processing Record 26 of Set 3 | bathsheba
# Processing Record 27 of Set 3 | kytlym
# City not found. Skipping...
# Processing Record 28 of Set 3 | tuatapere
# Processing Record 29 of Set 3 | acari
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | nan
# Processing Record 32 of Set 3 | fallon
# Processing Record 33 of Set 3 | nanaimo
# Processing Record 34 of Set 3 | alice springs
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | shelburne
# Processing Record 37 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 3 | mpika
# Processing Record 39 of Set 3 | broome
# Processing Record 40 of Set 3 | siquijor
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | lakes entrance
# Processing Record 43 of Set 3 | vuktyl
# Processing Record 44 of Set 3 | ancud
# Processing Record 45 of Set 3 | kununurra
# Processing Record 46 of Set 3 | verkhoyansk
# Processing Record 47 of Set 3 | paamiut
# Processing Record 48 of Set 3 | klaksvik
# Processing Record 49 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 50 of Set 3 | monrovia
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | mahon
# Processing Record 3 of Set 4 | kijang
# Processing Record 4 of Set 4 | novoorsk
# Processing Record 5 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 4 | acarau
# Processing Record 7 of Set 4 | benxi
# Processing Record 8 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 4 | kargasok
# Processing Record 10 of Set 4 | russell
# Processing Record 11 of Set 4 | arlit
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | ismailia
# Processing Record 14 of Set 4 | lagoa
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | galle
# Processing Record 17 of Set 4 | bongandanga
# Processing Record 18 of Set 4 | ranong
# Processing Record 19 of Set 4 | dikson
# Processing Record 20 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 4 | bonwapitse
# Processing Record 22 of Set 4 | gull lake
# Processing Record 23 of Set 4 | saint-philippe
# Processing Record 24 of Set 4 | katsuura
# Processing Record 25 of Set 4 | coquimbo
# Processing Record 26 of Set 4 | barrow
# Processing Record 27 of Set 4 | arrifes
# Processing Record 28 of Set 4 | cabedelo
# Processing Record 29 of Set 4 | shache
# Processing Record 30 of Set 4 | los llanos de aridane
# Processing Record 31 of Set 4 | buena vista
# Processing Record 32 of Set 4 | erice
# Processing Record 33 of Set 4 | chistogorskiy
# Processing Record 34 of Set 4 | asfi
# Processing Record 35 of Set 4 | cockburn town
# Processing Record 36 of Set 4 | port macquarie
# Processing Record 37 of Set 4 | egvekinot
# Processing Record 38 of Set 4 | shenjiamen
# Processing Record 39 of Set 4 | aitape
# Processing Record 40 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | kondinskoye
# Processing Record 43 of Set 4 | ambilobe
# Processing Record 44 of Set 4 | chimore
# Processing Record 45 of Set 4 | fairbanks
# Processing Record 46 of Set 4 | gravdal
# Processing Record 47 of Set 4 | linxia
# Processing Record 48 of Set 4 | koulikoro
# Processing Record 49 of Set 4 | araouane
# Processing Record 50 of Set 4 | thunder bay
# Processing Record 1 of Set 5 | panguipulli
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | mar del plata
# Processing Record 5 of Set 5 | arequipa
# Processing Record 6 of Set 5 | weyburn
# Processing Record 7 of Set 5 | akyab
# Processing Record 8 of Set 5 | berlevag
# Processing Record 9 of Set 5 | ballitoville
# Processing Record 10 of Set 5 | lucapa
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | san quintin
# Processing Record 13 of Set 5 | kiama
# Processing Record 14 of Set 5 | padang
# Processing Record 15 of Set 5 | narsaq
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | bubaque
# Processing Record 18 of Set 5 | kermanshah
# Processing Record 19 of Set 5 | hasaki
# Processing Record 20 of Set 5 | nanganga
# Processing Record 21 of Set 5 | gouyave
# Processing Record 22 of Set 5 | barbacoas
# Processing Record 23 of Set 5 | waingapu
# Processing Record 24 of Set 5 | cochrane
# Processing Record 25 of Set 5 | alofi
# Processing Record 26 of Set 5 | teguise
# Processing Record 27 of Set 5 | sinnamary
# Processing Record 28 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 5 | frontera
# Processing Record 30 of Set 5 | vardo
# Processing Record 31 of Set 5 | mayumba
# Processing Record 32 of Set 5 | saint-augustin
# Processing Record 33 of Set 5 | santa isabel do rio negro
# Processing Record 34 of Set 5 | pokhara
# Processing Record 35 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 5 | puerto del rosario
# Processing Record 37 of Set 5 | verkhnyaya toyma
# Processing Record 38 of Set 5 | sur
# Processing Record 39 of Set 5 | ixtapa
# Processing Record 40 of Set 5 | scottsbluff
# Processing Record 41 of Set 5 | upernavik
# Processing Record 42 of Set 5 | caravelas
# Processing Record 43 of Set 5 | inyonga
# Processing Record 44 of Set 5 | kahului
# Processing Record 45 of Set 5 | portoferraio
# Processing Record 46 of Set 5 | victoria
# Processing Record 47 of Set 5 | lorengau
# Processing Record 48 of Set 5 | terlizzi
# Processing Record 49 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 5 | chokurdakh
# Processing Record 1 of Set 6 | murbad
# Processing Record 2 of Set 6 | savanur
# Processing Record 3 of Set 6 | half moon bay
# Processing Record 4 of Set 6 | jiazi
# Processing Record 5 of Set 6 | huarmey
# Processing Record 6 of Set 6 | buchanan
# Processing Record 7 of Set 6 | kutum
# Processing Record 8 of Set 6 | tawau
# Processing Record 9 of Set 6 | boa vista
# Processing Record 10 of Set 6 | khatanga
# Processing Record 11 of Set 6 | xushan
# Processing Record 12 of Set 6 | adrar
# Processing Record 13 of Set 6 | garden city
# Processing Record 14 of Set 6 | ola
# Processing Record 15 of Set 6 | constitucion
# Processing Record 16 of Set 6 | grindavik
# Processing Record 17 of Set 6 | zhigansk
# Processing Record 18 of Set 6 | wyszkow
# Processing Record 19 of Set 6 | nouadhibou
# Processing Record 20 of Set 6 | dingle
# Processing Record 21 of Set 6 | dunedin
# Processing Record 22 of Set 6 | malindi
# Processing Record 23 of Set 6 | tall kayf
# Processing Record 24 of Set 6 | laguna
# Processing Record 25 of Set 6 | nynashamn
# Processing Record 26 of Set 6 | bethel
# Processing Record 27 of Set 6 | rorvik
# Processing Record 28 of Set 6 | krasyliv
# Processing Record 29 of Set 6 | salalah
# Processing Record 30 of Set 6 | faanui
# Processing Record 31 of Set 6 | namatanai
# Processing Record 32 of Set 6 | meulaboh
# Processing Record 33 of Set 6 | portland
# Processing Record 34 of Set 6 | lerwick
# Processing Record 35 of Set 6 | sibolga
# Processing Record 36 of Set 6 | itacoatiara
# Processing Record 37 of Set 6 | garmsar
# Processing Record 38 of Set 6 | pecos
# Processing Record 39 of Set 6 | trapani
# Processing Record 40 of Set 6 | wanning
# Processing Record 41 of Set 6 | necochea
# Processing Record 42 of Set 6 | samarai
# Processing Record 43 of Set 6 | adeje
# Processing Record 44 of Set 6 | san patricio
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | carnarvon
# Processing Record 47 of Set 6 | naushahro firoz
# Processing Record 48 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 6 | nador
# Processing Record 50 of Set 6 | vung tau
# Processing Record 1 of Set 7 | mahajanga
# Processing Record 2 of Set 7 | mont-de-marsan
# Processing Record 3 of Set 7 | severnyy
# Processing Record 4 of Set 7 | esperance
# Processing Record 5 of Set 7 | vao
# Processing Record 6 of Set 7 | bajina basta
# Processing Record 7 of Set 7 | merauke
# Processing Record 8 of Set 7 | shanghai
# Processing Record 9 of Set 7 | marica
# Processing Record 10 of Set 7 | mountain home
# Processing Record 11 of Set 7 | liberal
# Processing Record 12 of Set 7 | ponta do sol
# Processing Record 13 of Set 7 | mareeba
# Processing Record 14 of Set 7 | mina
# Processing Record 15 of Set 7 | souillac
# Processing Record 16 of Set 7 | beaupre
# Processing Record 17 of Set 7 | okhotsk
# Processing Record 18 of Set 7 | novopokrovka
# Processing Record 19 of Set 7 | tabuk
# Processing Record 20 of Set 7 | conde
# Processing Record 21 of Set 7 | bengkulu
# Processing Record 22 of Set 7 | ponnani
# Processing Record 23 of Set 7 | hofn
# Processing Record 24 of Set 7 | slyudyanka
# Processing Record 25 of Set 7 | pitimbu
# Processing Record 26 of Set 7 | tabou
# Processing Record 27 of Set 7 | thinadhoo
# Processing Record 28 of Set 7 | port keats
# Processing Record 29 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 7 | flinders
# Processing Record 31 of Set 7 | verkhnetulomskiy
# Processing Record 32 of Set 7 | gorele
# Processing Record 33 of Set 7 | mwinilunga
# Processing Record 34 of Set 7 | abu samrah
# Processing Record 35 of Set 7 | kaili
# Processing Record 36 of Set 7 | port alfred
# Processing Record 37 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 7 | burns lake
# Processing Record 39 of Set 7 | coos bay
# Processing Record 40 of Set 7 | carutapera
# Processing Record 41 of Set 7 | mnogovershinnyy
# Processing Record 42 of Set 7 | wonthaggi
# Processing Record 43 of Set 7 | sao filipe
# Processing Record 44 of Set 7 | lanquin
# Processing Record 45 of Set 7 | kavaratti
# Processing Record 46 of Set 7 | spirit river
# Processing Record 47 of Set 7 | salinopolis
# Processing Record 48 of Set 7 | hualmay
# Processing Record 49 of Set 7 | oranjemund
# Processing Record 50 of Set 7 | andarab
# City not found. Skipping...
# Processing Record 1 of Set 8 | sandwick
# Processing Record 2 of Set 8 | pangnirtung
# Processing Record 3 of Set 8 | pevek
# Processing Record 4 of Set 8 | pacific grove
# Processing Record 5 of Set 8 | kasempa
# Processing Record 6 of Set 8 | krasnyy chikoy
# Processing Record 7 of Set 8 | utrecht
# Processing Record 8 of Set 8 | papara
# Processing Record 9 of Set 8 | airai
# Processing Record 10 of Set 8 | mahebourg
# Processing Record 11 of Set 8 | tullahoma
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | monroe
# Processing Record 14 of Set 8 | ayagoz
# Processing Record 15 of Set 8 | vila franca do campo
# Processing Record 16 of Set 8 | nome
# Processing Record 17 of Set 8 | rosita
# Processing Record 18 of Set 8 | koslan
# Processing Record 19 of Set 8 | chara
# Processing Record 20 of Set 8 | keti bandar
# Processing Record 21 of Set 8 | nyurba
# Processing Record 22 of Set 8 | otane
# Processing Record 23 of Set 8 | tekeli
# Processing Record 24 of Set 8 | akureyri
# Processing Record 25 of Set 8 | denpasar
# Processing Record 26 of Set 8 | galatas
# Processing Record 27 of Set 8 | bodden town
# Processing Record 28 of Set 8 | chifeng
# Processing Record 29 of Set 8 | aranos
# Processing Record 30 of Set 8 | rognan
# Processing Record 31 of Set 8 | la ronge
# Processing Record 32 of Set 8 | henties bay
# Processing Record 33 of Set 8 | broken hill
# Processing Record 34 of Set 8 | goksun
# Processing Record 35 of Set 8 | mukhen
# Processing Record 36 of Set 8 | greenwood
# Processing Record 37 of Set 8 | sanmenxia
# Processing Record 38 of Set 8 | longyearbyen
# Processing Record 39 of Set 8 | tondon
# Processing Record 40 of Set 8 | susanville
# Processing Record 41 of Set 8 | murzzuschlag
# Processing Record 42 of Set 8 | ye
# City not found. Skipping...
# Processing Record 43 of Set 8 | dahanu
# Processing Record 44 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 8 | arman
# Processing Record 46 of Set 8 | yerbogachen
# Processing Record 47 of Set 8 | tessalit
# Processing Record 48 of Set 8 | rio grande
# Processing Record 49 of Set 8 | cayenne
# Processing Record 50 of Set 8 | sao felix do xingu
# Processing Record 1 of Set 9 | zeya
# Processing Record 2 of Set 9 | misratah
# Processing Record 3 of Set 9 | hamilton
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | dobrinka
# Processing Record 6 of Set 9 | aykhal
# Processing Record 7 of Set 9 | coihaique
# Processing Record 8 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 9 | svetlaya
# Processing Record 11 of Set 9 | valparaiso
# Processing Record 12 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 14 of Set 9 | husavik
# Processing Record 15 of Set 9 | sorong
# Processing Record 16 of Set 9 | dong hoi
# Processing Record 17 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 9 | thaton
# Processing Record 19 of Set 9 | ouargaye
# Processing Record 20 of Set 9 | yarada
# Processing Record 21 of Set 9 | strezhevoy
# Processing Record 22 of Set 9 | saint-pierre
# Processing Record 23 of Set 9 | narasannapeta
# Processing Record 24 of Set 9 | homer
# Processing Record 25 of Set 9 | cueto
# Processing Record 26 of Set 9 | komsomolskiy
# Processing Record 27 of Set 9 | asau
# Processing Record 28 of Set 9 | doha
# Processing Record 29 of Set 9 | staryy nadym
# Processing Record 30 of Set 9 | havelock
# Processing Record 31 of Set 9 | pithora
# Processing Record 32 of Set 9 | san policarpo
# Processing Record 33 of Set 9 | ambarawa
# Processing Record 34 of Set 9 | bulaevo
# Processing Record 35 of Set 9 | mbaiki
# Processing Record 36 of Set 9 | lysa hora
# Processing Record 37 of Set 9 | sola
# Processing Record 38 of Set 9 | kyrylivka
# Processing Record 39 of Set 9 | chimbote
# Processing Record 40 of Set 9 | lydenburg
# Processing Record 41 of Set 9 | biak
# Processing Record 42 of Set 9 | abonnema
# Processing Record 43 of Set 9 | fayaoue
# Processing Record 44 of Set 9 | tsogni
# Processing Record 45 of Set 9 | malatya
# Processing Record 46 of Set 9 | gat
# Processing Record 47 of Set 9 | kankon
# Processing Record 48 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 9 | dawlatabad
# Processing Record 50 of Set 9 | taraz
# Processing Record 1 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 10 | puerto madryn
# Processing Record 3 of Set 10 | libreville
# Processing Record 4 of Set 10 | zhigalovo
# Processing Record 5 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 6 of Set 10 | ambon
# Processing Record 7 of Set 10 | atar
# Processing Record 8 of Set 10 | corrente
# Processing Record 9 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 10 | porto novo
# Processing Record 11 of Set 10 | beypur
# City not found. Skipping...
# Processing Record 12 of Set 10 | krasnoselkup
# Processing Record 13 of Set 10 | manado
# Processing Record 14 of Set 10 | entebbe
# Processing Record 15 of Set 10 | acapulco
# Processing Record 16 of Set 10 | yangambi
# Processing Record 17 of Set 10 | grinnell
# Processing Record 18 of Set 10 | caconda
# Processing Record 19 of Set 10 | chapleau
# Processing Record 20 of Set 10 | beloha
# Processing Record 21 of Set 10 | vanavara
# Processing Record 22 of Set 10 | miyako
# Processing Record 23 of Set 10 | nantucket
# Processing Record 24 of Set 10 | saldanha
# Processing Record 25 of Set 10 | poopo
# Processing Record 26 of Set 10 | sabzevar
# Processing Record 27 of Set 10 | wilhelmsburg
# Processing Record 28 of Set 10 | bilibino
# Processing Record 29 of Set 10 | flin flon
# Processing Record 30 of Set 10 | hami
# Processing Record 31 of Set 10 | pankovka
# Processing Record 32 of Set 10 | soddy-daisy
# Processing Record 33 of Set 10 | nalut
# Processing Record 34 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 10 | tahta
# Processing Record 36 of Set 10 | manta
# Processing Record 37 of Set 10 | el dorado
# Processing Record 38 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 10 | betioky
# Processing Record 40 of Set 10 | talas
# Processing Record 41 of Set 10 | belaya gora
# Processing Record 42 of Set 10 | nemuro
# Processing Record 43 of Set 10 | ondjiva
# Processing Record 44 of Set 10 | coahuayana
# Processing Record 45 of Set 10 | zhangjiakou
# Processing Record 46 of Set 10 | codrington
# Processing Record 47 of Set 10 | nova olinda do norte
# Processing Record 48 of Set 10 | ayan
# Processing Record 49 of Set 10 | lira
# Processing Record 50 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 11 | ormara
# Processing Record 2 of Set 11 | srednekolymsk
# Processing Record 3 of Set 11 | emmett
# Processing Record 4 of Set 11 | soe
# Processing Record 5 of Set 11 | villazon
# Processing Record 6 of Set 11 | awbari
# Processing Record 7 of Set 11 | kaeo
# Processing Record 8 of Set 11 | rawson
# Processing Record 9 of Set 11 | sena madureira
# Processing Record 10 of Set 11 | rio gallegos
# Processing Record 11 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 12 of Set 11 | bunda
# Processing Record 13 of Set 11 | tondano
# Processing Record 14 of Set 11 | varnavino
# Processing Record 15 of Set 11 | waddan
# Processing Record 16 of Set 11 | bar harbor
# Processing Record 17 of Set 11 | deputatskiy
# Processing Record 18 of Set 11 | marrakesh
# Processing Record 19 of Set 11 | richards bay
# Processing Record 20 of Set 11 | margate
# Processing Record 21 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 11 | paita
# Processing Record 23 of Set 11 | kalianget
# Processing Record 24 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 11 | bereda
# Processing Record 26 of Set 11 | jumla
# Processing Record 27 of Set 11 | ulladulla
# Processing Record 28 of Set 11 | fort nelson
# Processing Record 29 of Set 11 | kisangani
# Processing Record 30 of Set 11 | lang son
# Processing Record 31 of Set 11 | graham
# Processing Record 32 of Set 11 | ondorhaan
# City not found. Skipping...
# Processing Record 33 of Set 11 | santa marta
# Processing Record 34 of Set 11 | conceicao da barra
# Processing Record 35 of Set 11 | vaitape
# Processing Record 36 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 11 | aklavik
# Processing Record 38 of Set 11 | paramonga
# Processing Record 39 of Set 11 | tomatlan
# Processing Record 40 of Set 11 | karratha
# Processing Record 41 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 42 of Set 11 | nanortalik
# Processing Record 43 of Set 11 | itoman
# Processing Record 44 of Set 11 | marsaxlokk
# Processing Record 45 of Set 11 | lagos
# Processing Record 46 of Set 11 | cairns
# Processing Record 47 of Set 11 | hamina
# Processing Record 48 of Set 11 | san cristobal
# Processing Record 49 of Set 11 | abnub
# Processing Record 50 of Set 11 | solnechnyy
# Processing Record 1 of Set 12 | mbandaka
# Processing Record 2 of Set 12 | raudeberg
# Processing Record 3 of Set 12 | sioux lookout
# Processing Record 4 of Set 12 | jilib
# Processing Record 5 of Set 12 | honningsvag
# Processing Record 6 of Set 12 | bukachacha
# Processing Record 7 of Set 12 | bousso
# Processing Record 8 of Set 12 | tommot
# Processing Record 9 of Set 12 | burgos
# Processing Record 10 of Set 12 | lere
# Processing Record 11 of Set 12 | tahoua
# Processing Record 12 of Set 12 | terney
# Processing Record 13 of Set 12 | maumere
# Processing Record 14 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 12 | pinawa
# Processing Record 16 of Set 12 | jampur
# Processing Record 17 of Set 12 | newport
# Processing Record 18 of Set 12 | naze
# Processing Record 19 of Set 12 | college
# Processing Record 20 of Set 12 | qarqin
# Processing Record 21 of Set 12 | savannah bight
# Processing Record 22 of Set 12 | dicabisagan
# Processing Record 23 of Set 12 | chiang khong
# Processing Record 24 of Set 12 | kapuskasing
# Processing Record 25 of Set 12 | jarjis
# City not found. Skipping...
# Processing Record 26 of Set 12 | katangli
# Processing Record 27 of Set 12 | irbeyskoye
# Processing Record 28 of Set 12 | zangakatun
# Processing Record 29 of Set 12 | kisaran
# Processing Record 30 of Set 12 | anadyr
# Processing Record 31 of Set 12 | tabora
# Processing Record 32 of Set 12 | saint-francois
# Processing Record 33 of Set 12 | capao da canoa
# Processing Record 34 of Set 12 | eisenerz
# Processing Record 35 of Set 12 | shimoda
# Processing Record 36 of Set 12 | marsh harbour
# Processing Record 37 of Set 12 | oistins
# Processing Record 38 of Set 12 | lasa
# Processing Record 39 of Set 12 | bima
# Processing Record 40 of Set 12 | zapolyarnyy
# Processing Record 41 of Set 12 | gunjur
# Processing Record 42 of Set 12 | haines junction
# Processing Record 43 of Set 12 | pradopolis
# Processing Record 44 of Set 12 | bairiki
# Processing Record 45 of Set 12 | akdagmadeni
# Processing Record 46 of Set 12 | ikom
# Processing Record 47 of Set 12 | trairi
# Processing Record 48 of Set 12 | nizhniy kuranakh
# Processing Record 49 of Set 12 | elk city
# Processing Record 50 of Set 12 | suntar
# Processing Record 1 of Set 13 | ascension
# Processing Record 2 of Set 13 | nauta
# Processing Record 3 of Set 13 | sorland
# Processing Record 4 of Set 13 | grootfontein
# Processing Record 5 of Set 13 | puerto lempira
# Processing Record 6 of Set 13 | maldonado
# Processing Record 7 of Set 13 | prachuap khiri khan
# Processing Record 8 of Set 13 | waipawa
# Processing Record 9 of Set 13 | kampot
# Processing Record 10 of Set 13 | copiapo
# Processing Record 11 of Set 13 | surt
# Processing Record 12 of Set 13 | campbell river
# Processing Record 13 of Set 13 | batagay-alyta
# Processing Record 14 of Set 13 | saint george
# Processing Record 15 of Set 13 | krasnoborsk
# Processing Record 16 of Set 13 | qaqortoq
# Processing Record 17 of Set 13 | astoria
# Processing Record 18 of Set 13 | pau brasil
# Processing Record 19 of Set 13 | cheney
# Processing Record 20 of Set 13 | fare
# Processing Record 21 of Set 13 | ilhabela
# Processing Record 22 of Set 13 | skibotn
# Processing Record 23 of Set 13 | mpwapwa
# Processing Record 24 of Set 13 | troitsko-pechorsk
# Processing Record 25 of Set 13 | proletariy
# Processing Record 26 of Set 13 | saint-denis
# Processing Record 27 of Set 13 | chkalovskoye
# Processing Record 28 of Set 13 | nuevo ideal
# Processing Record 29 of Set 13 | chapais
# Processing Record 30 of Set 13 | seshcha
# Processing Record 31 of Set 13 | esterhazy
# Processing Record 32 of Set 13 | kholtoson
# Processing Record 33 of Set 13 | duma
# Processing Record 34 of Set 13 | sidi bu zayd
# City not found. Skipping...
# Processing Record 35 of Set 13 | vanimo
# Processing Record 36 of Set 13 | yumen
# Processing Record 37 of Set 13 | ugoofaaru
# Processing Record 38 of Set 13 | guozhen
# Processing Record 39 of Set 13 | masaka
# Processing Record 40 of Set 13 | morros
# Processing Record 41 of Set 13 | nuevo progreso
# Processing Record 42 of Set 13 | cap malheureux
# Processing Record 43 of Set 13 | tagusao
# Processing Record 44 of Set 13 | inzer
# Processing Record 45 of Set 13 | clarence town
# Processing Record 46 of Set 13 | amarante do maranhao
# Processing Record 47 of Set 13 | port shepstone
# Processing Record 48 of Set 13 | calama
# Processing Record 49 of Set 13 | hit
# Processing Record 50 of Set 13 | ishigaki
# Processing Record 1 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 14 | butembo
# Processing Record 3 of Set 14 | bucerias
# Processing Record 4 of Set 14 | ituacu
# Processing Record 5 of Set 14 | zholymbet
# Processing Record 6 of Set 14 | pasni
# Processing Record 7 of Set 14 | wilbraham
# Processing Record 8 of Set 14 | bataipora
# Processing Record 9 of Set 14 | onega
# Processing Record 10 of Set 14 | tucuru
# Processing Record 11 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 14 | redlands
# Processing Record 13 of Set 14 | boende
# Processing Record 14 of Set 14 | staryy biser
# City not found. Skipping...
# Processing Record 15 of Set 14 | kalmunai
# Processing Record 16 of Set 14 | creston
# Processing Record 17 of Set 14 | jiwani
# Processing Record 18 of Set 14 | macenta
# Processing Record 19 of Set 14 | grand-santi
# Processing Record 20 of Set 14 | praya
# Processing Record 21 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 22 of Set 14 | hailar
# Processing Record 23 of Set 14 | fukue
# Processing Record 24 of Set 14 | ballina
# Processing Record 25 of Set 14 | pueblo
# Processing Record 26 of Set 14 | phalaborwa
# Processing Record 27 of Set 14 | charters towers
# Processing Record 28 of Set 14 | mehamn
# Processing Record 29 of Set 14 | kambia
# Processing Record 30 of Set 14 | mount isa
# Processing Record 31 of Set 14 | aleksandrovsk-sakhalinskiy
# Processing Record 32 of Set 14 | lompoc
# Processing Record 33 of Set 14 | prince rupert
# Processing Record 34 of Set 14 | hastings
# Processing Record 35 of Set 14 | salta
# Processing Record 36 of Set 14 | sokolo
# Processing Record 37 of Set 14 | pingliang
# Processing Record 38 of Set 14 | piacabucu
# Processing Record 39 of Set 14 | kulhudhuffushi
# Processing Record 40 of Set 14 | port blair
# Processing Record 41 of Set 14 | noumea
# Processing Record 42 of Set 14 | laurel
# Processing Record 43 of Set 14 | bertoua
# Processing Record 44 of Set 14 | sisimiut
# Processing Record 45 of Set 14 | palmer
# Processing Record 46 of Set 14 | almaznyy
# Processing Record 47 of Set 14 | kultuk
# Processing Record 48 of Set 14 | mezen
# Processing Record 49 of Set 14 | viedma
# Processing Record 50 of Set 14 | lithgow
# Processing Record 1 of Set 15 | sakaraha
# Processing Record 2 of Set 15 | aktau
# Processing Record 3 of Set 15 | leh
# Processing Record 4 of Set 15 | high level
# Processing Record 5 of Set 15 | borba
# Processing Record 6 of Set 15 | camacha
# Processing Record 7 of Set 15 | garowe
# Processing Record 8 of Set 15 | shingu
# Processing Record 9 of Set 15 | sept-iles
# Processing Record 10 of Set 15 | beliu
# Processing Record 11 of Set 15 | warrington
# Processing Record 12 of Set 15 | west carrollton city
# Processing Record 13 of Set 15 | hollins
# Processing Record 14 of Set 15 | marshalltown
# Processing Record 15 of Set 15 | lazaro cardenas
# Processing Record 16 of Set 15 | pskov
# Processing Record 17 of Set 15 | vetluga
# Processing Record 18 of Set 15 | shakiso
# Processing Record 19 of Set 15 | boyolangu
# Processing Record 20 of Set 15 | castrillon
# Processing Record 21 of Set 15 | roma
# Processing Record 22 of Set 15 | mahibadhoo
# Processing Record 23 of Set 15 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 24 of Set 15 | dagana
# Processing Record 25 of Set 15 | saint anthony
# Processing Record 26 of Set 15 | muisne
# Processing Record 27 of Set 15 | sekoma
# Processing Record 28 of Set 15 | itarema
# Processing Record 29 of Set 15 | mao
# Processing Record 30 of Set 15 | zary
# Processing Record 31 of Set 15 | valdivia
# Processing Record 32 of Set 15 | avera
# Processing Record 33 of Set 15 | disna
# Processing Record 34 of Set 15 | ulagan
# Processing Record 35 of Set 15 | craig
# Processing Record 36 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 37 of Set 15 | road town
# Processing Record 38 of Set 15 | waverly
# Processing Record 39 of Set 15 | barcelos
# Processing Record 40 of Set 15 | sao joao da barra
# Processing Record 41 of Set 15 | yaan
# Processing Record 42 of Set 15 | saint-georges
# Processing Record 43 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 44 of Set 15 | sungaipenuh
# Processing Record 45 of Set 15 | altayskoye
# Processing Record 46 of Set 15 | nanakuli
# Processing Record 47 of Set 15 | valleyview
# Processing Record 48 of Set 15 | ati
# Processing Record 49 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 50 of Set 15 | itaituba
# Processing Record 1 of Set 16 | xining
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Elizabeth City      US  36.29  -76.25     62.60        72          20
# 1    Novo Oriente      BR  -5.53  -40.77     82.27        47          59
# 2         Timmins      CA  48.47  -81.33     32.00        98          75
# 3     New Norfolk      AU -42.78  147.06     64.00        53          79
# 4    Punta Arenas      CL -53.15  -70.92     50.00        53          40
# 5     Yellowknife      CA  62.46 -114.35     10.40        78          75
# 6      Lavrentiya      RU  65.58 -171.00     30.78        97         100
# 7      Nikolskoye      RU  59.70   30.79     32.00        94          90
# 8        Menongue      AO -14.66   17.69     65.14        86          84
# 9            Lebu      CL -37.62  -73.65     54.48        66           3
#
#    Wind Speed Current Description
# 0        5.82          few clouds
# 1        3.13       broken clouds
# 2        2.24       broken clouds
# 3        1.99       broken clouds
# 4       26.40    scattered clouds
# 5        9.17          light snow
# 6        1.57     overcast clouds
# 7        6.71   light shower snow
# 8        2.44       broken clouds
# 9       17.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
